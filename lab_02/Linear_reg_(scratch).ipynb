# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahuldeb55/Machine-learning-laboratory/blob/main/lab_02/Linear_reg_(scratch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

plt.figure(figsize=(8, 6))
plt.scatter(X, y, alpha=0.7)
plt.xlabel('X (Feature)')
plt.ylabel('y (Target)')
plt.title('Generated Synthetic Data')
plt.grid(True)
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X]

theta = np.random.randn(2, 1)

print(f"Initial theta (theta0, theta1):\n{theta}")
# Out:
# Initial theta (theta0, theta1):
# [[0.01300189]
#  [1.45353408]]

# %%
learning_rate = 0.1
n_iterations = 1000
m = len(X)

cost_history = []

for iteration in range(n_iterations):
    predictions = X_b.dot(theta)
    errors = predictions - y
    gradients = (1/m) * X_b.T.dot(errors)
    theta = theta - learning_rate * gradients

    cost = (1/(2*m)) * np.sum(errors**2)
    cost_history.append(cost)

print(f"Optimal theta (theta0, theta1) found by Gradient Descent:\n{theta}")
# Out:
# Optimal theta (theta0, theta1) found by Gradient Descent:
# [[4.21509609]
#  [2.77011344]]

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
predictions_new = X_new_b.dot(theta)

print(f"Predictions for X_new:\n{predictions_new}")
# Out:
# Predictions for X_new:
# [[4.21509609]
#  [9.75532298]]

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(X, y, alpha=0.7, label='Original Data')
plt.plot(X_new, predictions_new, 'r-', linewidth=2, label='Regression Line')
plt.xlabel('X (Feature)')
plt.ylabel('y (Target)')
plt.title('Simple Linear Regression Fit')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(n_iterations), cost_history, 'b-')
plt.xlabel('Iteration')
plt.ylabel('Cost (MSE)')
plt.title('Cost Function Convergence during Gradient Descent')
plt.grid(True)

plt.tight_layout()
plt.show()
